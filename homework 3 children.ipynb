# %%
import pandas as pd
import numpy as np
import re

# %%
df_minjust = pd.read_csv('data/Minjust2018.csv', 
                 header=None, 
                 usecols=[4, 27, 28, 33])
df_minjust.fillna('', inplace=True)
df_minjust.rename(columns={4: 'company_name', 
                           27: 'director', 
                           28: 'activity', 
                           33: 'founders'},
                  inplace = True)

# %%
df_minjust

# %%
df_decl = pd.read_csv('data/declaration.csv', 
                      header=None, 
                      usecols=[1, 2, 3, 4, 5])
df_decl.fillna('', inplace=True)
df_decl.rename(columns={1: 'surname', 
                        2: 'name', 
                        3: 'patronymic', 
                        4: 'workplace',
                        5: 'position'},
                  inplace = True)

# %%
df_decl

# %%
columns = ['company_name', 'director', 'activity', 'founders', 'surname', 'name', 'patronymic', 'workplace', 'position']
result = pd.DataFrame(columns=columns)

# %%
def search_df(df, column, pattern):
    return df.loc[df[column].str.contains(pattern)]

def child_regex(surname, name):
    pattern = re.compile(surname +
                         r'а?\s+\w+\s+' + # First name
                         remove_vowels(name) + # Patronymic
                         r'|' + 
                         r'\w+\s+' + # First name
                         remove_vowels(name) + r'\w+\s+' + # Patronymic
                         surname,
                         re.IGNORECASE)
    return pattern

def remove_vowels(name):
    while True:
        if name[-1] not in ['а', 'о', 'и', 'е', 'ё', 'э', 'ы', 'у', 'ю', 'я', 'й']:
            break
        else:
            name = name[: -1]
    return name

# %%
for index, row in df_decl.loc[568: 638].iterrows():
    search = search_df(df_minjust, 'founders', child_regex(row['surname'], row['name'])).copy()
    for column in df_decl.columns:
        search[column] = row[column]
    result = result.append(search, ignore_index=True)

# %%
result
# Out:
#                                          company_name  \
# 0                                     ООО "Касиеткан"
# 1                          Общественный фонд "СЕРДАР"
# 2   Учреждение "Редакция частной газеты "УЛУТ ЫЙМАНЫ"
# 3                 Общественное объединение "Биллайен"
# 4   Общество с ограниченной ответственностью "Белл...
# 5   Общество с ограниченной ответственностью "СиМа...
# 6     Общественный фонд "Поддержки и развития спорта"
# 7     Общественный фонд "Поддержки и развития спорта"
# 8   Общество с ограниченной ответственностью "Прем...
# 9   Общество с ограниченной ответственностью "GPS"...
# 10  Общество с ограниченной ответственностью "Прав...
# 11  Общественное объединение "Национальный центр м...
# 12            Общественное объединение «Бала Дүйнөсү»
# 13  Общество с дополнительной ответственностью Лом...
# 14  Общество с ограниченной ответственностью "Мирс...
# 15  Общество с ограниченной ответственностью «Азия...
# 16            ОсОО "Евро Трак Центр Бишкек" ИУ-Турция
# 17  Сельскохозяйственный коммерческий производстве...
# 18  Общество с ограниченной ответственностью "Гиир...
#
#                                director  \
# 0           Молдалиева Аида Орозбековна
# 1         Рязанцев Андрей Александрович
# 2       Молдалиева Муххабат Орозбековна
# 3              Исмаилов Данияр Абалович
# 4             Исмаилов Данияр Абалович
# 5            Осмонов Эрмек Бактыбекович
# 6       Нарындыков Аркарбек Эсентурович
# 7            Абдыгулова Асель Мисировна
# 8         Исмаилов Арафат Сайдахматович
# 9             Искаков Тариэль Мелисович
# 10        Чакарбаев Мирлан Советбекович
# 11      Кожоярова Гулсина Жолдошбековна
# 12          Чернышева Марина Викторовна
# 13         Джолдошева Лола Бактыбековна
# 14        Муратов Мирлан Кубанычбекович
# 15  Токтомамбетов Рахатбек Турдубекович
# 16  токтомамбетов рахатбек турдубекович
# 17                   Шермамбетов Муктар
# 18                              Эр Иляс
#
#                                              activity  \
# 0
# 1        Деятельность прочих ассоциаций  и обидинений
# 2
# 3   Деятельность прочих общественных организаций, ...
# 4   Деятельность агентов по оптовой торговле товар...
# 5                      Прочая спортивная деятельность
# 6   Деятельность прочих общественных организаций, ...
# 7   Деятельность прочих общественных организаций, ...
